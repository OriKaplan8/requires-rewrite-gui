# %% [markdown]
# # Initialization of MongoDB Connection
#
# This section of the code initializes the necessary Python libraries and sets up the connection to a MongoDB database. Below is an explanation of each component:
#
# ## Libraries Imported
#
# - **pymongo**: Used to work with MongoDB from Python. This library enables the creation of a client to interact with the database.
# - **datetime**: Provides classes for manipulating dates and times. It's used here to record timestamps when updating or inserting documents.
# - **json**: Supports JSON parsing. This module enables loading and parsing JSON data from files or strings.
#
# ## Database Connection
#
# - **Connection String**: A string that specifies the MongoDB server to connect to, including credentials and other connection options.
# - **Client Setup**: The `MongoClient` object is created using the connection string, which facilitates operations like inserting, retrieving, updating, and deleting documents.
# - **Database Selection**: Specifies the database (`require_rewrite_b`) from the MongoDB server to be used for operations.
#
# This setup is essential for performing any database operations that follow in the subsequent code.

# %%
#initlize eveything
from pymongo import MongoClient #mongo libary for the server
import datetime #for the time
import json #for the json files
connection_string = "mongodb+srv://ori:CqxF0bLlZoX2OQoD@cluster0.agjlk.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0" #the connection string, the adress of the server 
client = MongoClient(connection_string)
db = client.require_rewrite_b #the name of the database

# %% [markdown]
# # Database Functions for JSON Data Management
#
# This document outlines various Python functions designed for managing JSON data in a MongoDB database. These functions enable adding, updating, retrieving, and deleting JSON templates and annotations.
#
# ## Functions
#
# ### `add_or_update_json_template_in_db`
#
# - **Purpose**: Adds or updates a JSON template in the MongoDB collection. These templates serve as the basis for annotations, which users can select and annotate.
# - **Parameters**:
#   - `project_name` (str): Name of the project.
#   - `file_id` (str): ID of the file.
#   - `json_data` (dict): JSON data to be added.
#   - `overwrite` (bool): If true, updates the document if already exists; otherwise, inserts new.
# - **Returns**: None.
#
# ### `retrieve_json_template_by_file_id`
#
# - **Purpose**: Retrieves the JSON template based on file ID from the MongoDB collection.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: JSON data as a dictionary.
#
# ### `retrieve_annotations_by_file_id`
#
# - **Purpose**: Retrieves all annotations for a given file ID. Initially, the JSON data in annotations contains fields set to null to indicate that they have not been annotated.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: A dictionary containing annotations, indexed by username. As users interact with the annotation software, fields that are annotated are updated with actual values.
#
# ### `retrieve_annotation_by_user_and_file_id`
#
# - **Purpose**: Retrieves the annotated file for a specific user and file ID. The annotations start with null values and are populated with data as the user performs annotations.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
#   - `username` (str): Username of the annotator.
# - **Returns**: JSON data of the annotated file, if found. Fields are initially set to null and updated as the user annotates them.
#
# ### `delete_json_template_and_annotations_by_file_id`
#
# - **Purpose**: Deletes a JSON template and all associated annotations based on file ID.
# - **Parameters**:
#   - `file_id` (str): ID of the file.
# - **Returns**: None.
#
# ### `load_json_from_file`
#
# - **Purpose**: Loads JSON data from a file.
# - **Parameters**:
#   - `file_path` (str): Path to the JSON file.
# - **Returns**: JSON data as a dictionary.

# %%
def add_or_update_json_template_in_db(project_name, file_id, json_data, overwrite=False):
    """
    Adds a JSON template to the MongoDB collection.

    Parameters:
    - project_name (str): The name of the project.
    - file_id (str): The ID of the file.
    - json_data (dict): The JSON data to be added.
    - overwrite (bool): If True, the document will be updated if it exists. If False, the document will only be inserted if it doesn't exist.

    Returns:
    None
    """
    collection = db.json_batches
    query = {'file_id': file_id}

    if overwrite:
        # Update the document if it exists, or insert if it doesn't
        my_values = {"$set": {'file_id': file_id, 'json_data': json_data, 'project_name': project_name,
                              'annotated': False, 'uploaded': datetime.datetime.now()}}
    else:
        # Only set these fields if the document does not exist and is being inserted
        my_values = {"$setOnInsert": {'file_id': file_id, 'json_data': json_data, 'project_name': project_name,
                                      'annotated': False, 'uploaded': datetime.datetime.now()}}

    update_result = collection.update_one(query, my_values, upsert=True)
    
    if update_result.matched_count > 0:
        print(f"Document with file_id {file_id} updated.")
    elif update_result.upserted_id is not None:
        print(f"New document inserted with id {update_result.upserted_id}.")
    else:
        print("No changes made to the database.")
        
def retrieve_json_template_by_file_id(file_id):
    """
    Retrieves the JSON data from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to retrieve the JSON data for.

    Returns:
        dict: The JSON data retrieved from the MongoDB collection.

    Raises:
        None

    """
    collection = db.json_batches
    query = {'file_id': file_id}
    result = collection.find_one(query)
    if result:
        print("Found document:")
        print(result['json_data'])  # Print only the json_data field
        return result['json_data']  # Return only the json_data field
    else:
        print("No document found with the specified project name and file ID.")
        return None

def retrieve_annotations_by_file_id(file_id):
    """
    Retrieves the annotated JSON data from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to retrieve the annotated JSON data for.

    Returns:
        dict: The annotated JSON data retrieved from the MongoDB collection.

    Raises:
        None

    """
    collection = db.json_annotations
    query = {'file_id': file_id}
    result = collection.find(query)
    json_data = {}
    if result is not  None:
        for document in result:

            json_data[document["username"]] = document["json_data"]
                
     
        return json_data  # Return only the json_data field
    else:
        print("No document found with the specified project name and file ID.")
        return None
    
def retrieve_annotation_by_user_and_file_id(file_id, username):
    """
    Retrieves the annotated file of a specific annotator from the MongoDB collection.

    Parameters:
    - file_id (str): The ID of the file to retrieve.
    - username (str): The username of the annotator.

    Returns:
    - json_data (dict): The JSON data of the annotated file, if found.
    - None: If no document is found with the specified file ID or username.
    """

    collection = db.json_annotations
    query = {'file_id': file_id}
    result = collection.find_one(query)
    json_data = {}
    if result is not None:
        query = {'file_id': file_id, 'username': username}
        result = collection.find_one(query)
        if result is not None:
            json_data = result["json_data"]
            return json_data  # Return only the json_data field
        else: 
            print("No document found with the specified username.")
            return None
    else:
        print("No document found with the specified file ID.")
        return None
    
def delete_json_template_and_annotations_by_file_id(file_id):
    """
    Deletes a JSON template from the MongoDB collection based on the specified file ID.

    Args:
        file_id (str): The ID of the file to delete.

    Returns:
        None

    Raises:
        None

    """
    collection = db.json_batches
    query = {'file_id': file_id}
    result = collection.delete_one(query)
    if result.deleted_count > 0:
        print(f"Document with file_id {file_id} deleted.")

        collection = db.json_annotations
        query = {'file_id': file_id}
        result = collection.delete_many(query)
        print(f"Deleted {result.deleted_count} annotations for file_id {file_id}.")

    else:
        print("No document found with the specified file ID.")

def load_json_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
        return data
    except FileNotFoundError:
        raise Exception(f"Cannot find the json file: {file_path}. is the path correct? is it a json file?")

# %% [markdown]
# Example of retrieve_annotation_by_user_and_file_id:
#  - returns the annotated json file ori is currently annotating

# %%
retrieve_annotation_by_user_and_file_id("asi-23_4", "ori")
# Out:
# {'QReCC-Train_4784': {'1': {'sample_id': 'QReCC-Train_4784_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4784_1',
#     'original_question': 'What happened with Kate Tsui in 2007?',
#     'answer': 'Kate Tsui earned the Most Improved Female Artist award from the TVB Anniversary Awards 2007.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4784_2',
#     'original_question': 'What happened in 2008?',
#     'answer': 'Kate Tsui earned her a Top 5 position in the Best Supporting Actress category of the TVB Anniversary Awards 2008.'}]},
#  'QReCC-Train_63': {'1': {'sample_id': 'QReCC-Train_63_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_63_1',
#     'original_question': 'Where was Yui Horie born?',
#     'answer': 'Yui Horie was born in Tokyo'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_63_2',
#     'original_question': 'What happened in the early life?',
#     'answer': 'Yui Horie spent much of her younger years as a latchkey kid. As an only child she would spend most of her time alone, playing outside of her residence'}]},
#  'QReCC-Train_1883': {'1': {'sample_id': 'QReCC-Train_1883_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1883_1',
#     'original_question': 'What is the Franken amendment?',
#     'answer': 'Bill that would forbid federal contractors from forcing victims of sexual assault, battery and discrimination to submit to binding arbitration and thereby prohibiting them from going to court.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1883_2',
#     'original_question': 'How did it proceed?',
#     'answer': 'The amendment passed 68 to 30 with all opposition coming from Republicans including Vitter.'}]},
#  'QReCC-Train_7455': {'1': {'sample_id': 'QReCC-Train_7455_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7455_1',
#     'original_question': 'how long is life in prison in south africa',
#     'answer': "Life imprisonment in South Africa has an indeterminate length and may last for the remainder of the offender's life."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7455_2',
#     'original_question': 'is there a parole hearing for inmates who were sentenced to life imprisonment',
#     'answer': 'A prisoner sentenced to life imprisonment in South Africa must be given a parole hearing after having served 25 years.'}]},
#  'QReCC-Train_1354': {'1': {'sample_id': 'QReCC-Train_1354_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_1354_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_1354_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1354_1',
#     'original_question': 'Did Mia Hamm play for another team before coming to Washington?',
#     'answer': "The North Carolina Tar Heels women's soccer team."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1354_2',
#     'original_question': 'Was this her first team?',
#     'answer': 'As a high school freshman and sophomore, Mia Hamm played soccer for Notre Dame Catholic High School.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_1354_3',
#     'original_question': 'What position did she play on the team?',
#     'answer': 'Mia Hamm often started as a forward.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_1354_4',
#     'original_question': 'What was her record in 2001?',
#     'answer': "Mia Hamm played in 19 of the Freedom's 21 matches during the 2001 season."}]},
#  'QReCC-Train_5399': {'1': {'sample_id': 'QReCC-Train_5399_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_5399_1',
#     'original_question': 'When was Rhapsody in Blue started?',
#     'answer': 'Rhapsody in Blue is a 1924 musical composition by the American composer George Gershwin.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_5399_2',
#     'original_question': 'Who started it?',
#     'answer': 'At Aeolian Hall in New York City on November 1, 1923, the bandleader Paul Whiteman decided to attempt something more ambitious.'}]},
#  'QReCC-Train_6870': {'1': {'sample_id': 'QReCC-Train_6870_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_6870_3',
#    'requires_rewrite': 1,
#    'enough_context': 0},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6870_1',
#     'original_question': "What were Augusta Ada King, Countess of Lovelace's educational background in?",
#     'answer': "Her mother's obsession with rooting out any of the insanity of which she accused Byron was one of the reasons that Ada was taught mathematics from an early age."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6870_2',
#     'original_question': 'Did she attend a university?',
#     'answer': 'Through Charles Babbage, Ada began studying advanced mathematics with University of London professor Augustus de Morgan.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_6870_3',
#     'original_question': 'Does the article mention any of her tutors or mentors?',
#     'answer': 'She was privately schooled in mathematics and science by William Frend, William King, and Mary Somerville, the noted 19th-century researcher and scientific author.'}]},
#  'QReCC-Train_4326': {'1': {'sample_id': 'QReCC-Train_4326_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4326_1',
#     'original_question': "What interesting information is there about Rasputin's religious conversion?",
#     'answer': 'In 1897, Grigori Rasputin developed a renewed interest in religion and left Pokrovskoye to go on a pilgrimage.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4326_2',
#     'original_question': 'Where did he go on pilgrimage to?',
#     'answer': 'Grigori Rasputin visited the St. Nicholas Monastery at Verkhoturye in 1897.'}]},
#  'QReCC-Train_6510': {'1': {'sample_id': 'QReCC-Train_6510_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6510_1',
#     'original_question': "What was Émilie du Châtelet's contribution to philosophy?",
#     'answer': "Historical evidence indicates that Du Châtelet's work had a very significant influence on the philosophical and scientific conversations of the 1730s and 1740s."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6510_2',
#     'original_question': 'When did she start writing about philosophy',
#     'answer': 'By the age of twelve Émilie du Châtelet was fluent in Latin, Italian, Greek and German; she was later to publish translations into French of Greek and Latin plays and philosophy.'}]},
#  'QReCC-Train_619': {'1': {'sample_id': 'QReCC-Train_619_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_619_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_619_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_619_1',
#     'original_question': 'When was Love Jam by Ai Otsuka released?',
#     'answer': 'Love Jam is the second album by Ai Otsuka, released on 17 November 2004'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_619_2',
#     'original_question': 'What was a popular single off the album?',
#     'answer': 'Following the release of Love Jam, Ai Otsuka released the recut single Kuroge Wagyu Joshio Tan Yaki 680 Yen in February 2005.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_619_3',
#     'original_question': 'Did she win any awards for Happy Days?',
#     'answer': "Ai Otsuka's single Happy Days sold 163,433 units and reached third on the Oricon weekly chart."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_619_4',
#     'original_question': 'How many copies of Love Jam did she sell?',
#     'answer': "Ai Otsuka's album Love Jam debuted at the number one position and sold 224,381 units in its first week."}]},
#  'QReCC-Train_1373': {'1': {'sample_id': 'QReCC-Train_1373_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1373_1',
#     'original_question': 'What is Mesoamerica and its connection with Maya civilization?',
#     'answer': 'The Maya civilization developed within the Mesoamerican cultural area, which covers a region that spreads from northern Mexico southwards into Central America.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1373_2',
#     'original_question': 'What was the culture like?',
#     'answer': 'The Mesoamerican area gave rise to a series of cultural developments that included complex societies, agriculture, cities, monumental architecture, writing, and calendrical systems.'}]},
#  'QReCC-Train_7170': {'1': {'sample_id': 'QReCC-Train_7170_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7170_1',
#     'original_question': 'Did Harry Connick Jr. contribute music to When Harry Met Sally?',
#     'answer': 'Director Rob Reiner asked Harry Connick Jr. to provide a soundtrack for his romantic comedy, When Harry Met Sally.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7170_2',
#     'original_question': 'What notable songs are on the soundtrack?',
#     'answer': "The soundtrack consisted of several standards, including It Had to Be You, Let's Call the Whole Thing Off and Don't Get Around Much Anymore."}]},
#  'QReCC-Train_7195': {'1': {'sample_id': 'QReCC-Train_7195_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_7195_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_7195_4',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_7195_5',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 5,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7195_1',
#     'original_question': 'What blog did Yoani Sánchez start?',
#     'answer': 'Yoani Sánchez is best known for her blog, Generación Y or Generation Y.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7195_2',
#     'original_question': 'When did she start the blog?',
#     'answer': 'Yoani Sánchez launched her blog, Generation Y, on April 9, 2007.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_7195_3',
#     'original_question': 'What happened after she started the blog?',
#     'answer': 'The Generation Y blog was transferred to WordPress, and was eventually upgraded to allow comments by readers.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_7195_4',
#     'original_question': 'What is Desde Cuba?',
#     'answer': 'Desde Cuba is an on-line magazine and collection of individual blogs, of which Yoani Sánchez was the first.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_7195_5',
#     'original_question': 'What did she blog about?',
#     'answer': 'The first post used baseball fever to compare what Cubans are allowed to shout, and display on homemade posters and what they are not.'}]},
#  'QReCC-Train_8029': {'1': {'sample_id': 'QReCC-Train_8029_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_8029_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8029_1',
#     'original_question': 'how many sharps are in the key of A?',
#     'answer': 'The key of A major contains 3 sharps.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8029_2',
#     'original_question': 'what are the sharps?',
#     'answer': 'Those sharps would be F#, C#, and G#.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8029_3',
#     'original_question': 'how is the key spelled?',
#     'answer': 'A major is spelled: A, B, C#, D, E, F#, and G#.'}]},
#  'QReCC-Train_8285': {'1': {'sample_id': 'QReCC-Train_8285_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_8285_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_8285_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_8285_5',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   'number_of_turns': 5,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8285_1',
#     'original_question': 'what is the tallest building in richmond virginia',
#     'answer': 'Presently, the tallest building in Richmond, VA is the 29 story James Monroe Building.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8285_2',
#     'original_question': 'how tall is the building',
#     'answer': 'The James Monroe Building is the tallest building in Richmond at 137 meters'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8285_3',
#     'original_question': 'why does the building not seem that tall',
#     'answer': 'The location of the James Monroe Building at the bottom of a hill gives it the appearance of being roughly the same height as other buildings in the Richmond skyline.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_8285_4',
#     'original_question': 'when was the building completed',
#     'answer': 'The James Monroe Building was completed in 1981'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_8285_5',
#     'original_question': 'why was the twin tower not completed',
#     'answer': 'The James Monroe Building was intended to have a twin tower at the North end of its parking garage but the recession of the early 1980s ended the project'}]},
#  'QReCC-Train_9762': {'1': {'sample_id': 'QReCC-Train_9762_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_9762_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_9762_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_9762_1',
#     'original_question': 'who won raw tag team championship in hell in a cell',
#     'answer': 'Chad Gable defeated King Corbin by pinfall. R-Truth pinned Tamina to win the 24/7 Championship.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_9762_2',
#     'original_question': "what was the wrestler's early life like",
#     'answer': 'Betts was born in Saint Michael, Minnesota. He is a graduate of Northern Michigan University.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_9762_3',
#     'original_question': 'when was the wrestler signed to the wwe',
#     'answer': 'In November 2013, Betts signed a contract with the professional wrestling promotion WWE.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_9762_4',
#     'original_question': 'when did the wrestler make his television debut',
#     'answer': 'He made his television debut on the January 8, 2015 episode of NXT, losing to Tyler Breeze.'}]},
#  'QReCC-Train_828': {'1': {'sample_id': 'QReCC-Train_828_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_828_3',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_828_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_828_1',
#     'original_question': 'What did Johan Galtung think about the US?',
#     'answer': 'For Johan Galtung, the US is simultaneously a republic and an empire, a distinction he believes is highly relevant.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_828_2',
#     'original_question': 'Can you explain this distinction?',
#     'answer': 'The US is on one hand loved for its republican qualities, and on the other loathed by its enemies abroad for its perceived military aggressions.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_828_3',
#     'original_question': 'Did Galtung write anything about the US?',
#     'answer': 'In an article published in 2004, Galtung predicted that the US empire will decline and fall by 2020. He expanded on this hypothesis in his 2009 book.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_828_4',
#     'original_question': 'What was the title of his 2009 book?',
#     'answer': 'He expanded on his hypothesis in his 2009 book titled The Fall of the US Empire - and Then What? Successors, Regionalization or Globalization? US Fascism or US Blossoming?'}]},
#  'QReCC-Train_535': {'1': {'sample_id': 'QReCC-Train_535_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_535_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_535_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_535_1',
#     'original_question': 'When did Lou Gramm leave Foreigner?',
#     'answer': 'Lou Gramm announced his departure from Foreigner in May 1990 due to differences with Mick Jones, and to focus on his solo career.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_535_2',
#     'original_question': 'Why did he leave?',
#     'answer': 'Lou Gramm announced his departure from Foreigner in May 1990 due to differences with Mick Jones, and to focus on his solo career.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_535_3',
#     'original_question': 'What was his first solo album?',
#     'answer': 'Lou Gramm released his first solo album, Ready or Not, in January 1987 to critical acclaim.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_535_4',
#     'original_question': 'Did he have a second solo album?',
#     'answer': 'Long Hard Look is the second solo album from original Foreigner lead vocalist Lou Gramm, released in 1989'}]},
#  'QReCC-Train_3974': {'1': {'sample_id': 'QReCC-Train_3974_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_3974_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_3974_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_3974_5',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '5': {'sample_id': 'QReCC-Train_3974_6',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '6': {'sample_id': 'QReCC-Train_3974_7',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 7,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_3974_1',
#     'original_question': 'How did Evan Lysacek do in the 2005-2006 season?',
#     'answer': 'In the 2005–2006 season, Evan Lysacek again competed on the Grand Prix.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_3974_2',
#     'original_question': 'What else did he compete at?',
#     'answer': 'Evan Lysacek placed second at the 2005 Skate America, but it was clear that his Grease free skate was not working.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_3974_3',
#     'original_question': 'How did he place in other competitions?',
#     'answer': 'At the 2006 U.S. Championships, the de facto Olympic qualifier, Evan Lysacek was third after the short program, but pulled up to win the free skate, finishing second overall.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_3974_4',
#     'original_question': 'What else did he do?',
#     'answer': 'Evan Lysacek was named to the 2006 Winter Olympic team along with Johnny Weir and Matthew Savoie.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_3974_5',
#     'original_question': 'Are there any other competitions mentioned?',
#     'answer': 'Evan Lysacek ended his season by winning the bronze medal at the 2006 World Championships in Calgary, Alberta.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_3974_6',
#     'original_question': 'What other moves did he do?',
#     'answer': 'Evan Lysacek finished his free skate with eight triple jumps and was ranked third of the night. He finished fourth overall, seven points below the bronze at the 2006 Olympics.'},
#    {'turn_num': 6,
#     'sample_id': 'QReCC-Train_3974_7',
#     'original_question': 'What were some of his accomplishments?',
#     'answer': 'Evan Lysacek ended his season by winning the bronze medal at the 2006 World Championships in Calgary, Alberta.'}]},
#  'QReCC-Train_4613': {'1': {'sample_id': 'QReCC-Train_4613_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_4613_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_4613_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4613_1',
#     'original_question': "What is interesting about the Vienna Boys' Choir's recent history?",
#     'answer': "Gerald Wirth became the Vienna Boys' Choir's artistic director in 2001. However, since then, the choir has come under pressure."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4613_2',
#     'original_question': 'Why has it come under pressure?',
#     'answer': "The Vienna Boys' Choir has come under pressure to modernize and has faced criticism of their musical standards, leading to a split with the Vienna State Opera."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_4613_3',
#     'original_question': 'What changes did they make?',
#     'answer': "The Vienna Boys' Choir has for the first time had to advertise for recruits after a rival choir school was established by Ioan Holender, director of the opera company."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_4613_4',
#     'original_question': 'Has the choir had any controversies?',
#     'answer': "In 2010, following sexual abuse allegations from two former choristers stemming from the late 1960s and early 1980s, the Vienna Boys' Choir opened a confidential phone and e-mail hotline."}]},
#  'QReCC-Train_6580': {'1': {'sample_id': 'QReCC-Train_6580_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6580_1',
#     'original_question': "What was Notre Dame and Ara Parseghian's first national title?",
#     'answer': 'In 1966, Ara Parseghian guided Notre Dame to its first national championship since the Leahy era'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6580_2',
#     'original_question': 'How did they win it?',
#     'answer': 'They won because their offense was best in the nation in scoring, with an average of 36.2 points per game. The defense was second in the country in points allowed'}]},
#  'QReCC-Train_7241': {'1': {'sample_id': 'QReCC-Train_7241_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_7241_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_7241_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_7241_5',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '5': {'sample_id': 'QReCC-Train_7241_6',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '6': {'sample_id': 'QReCC-Train_7241_7',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '7': {'sample_id': 'QReCC-Train_7241_8',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 8,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7241_1',
#     'original_question': 'What was recorded for Modern Sounds in Country and Western Music?',
#     'answer': 'Modern Sounds in Country and Western Music was the 18th overall LP Charles had recorded.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7241_2',
#     'original_question': 'Who was the producer?',
#     'answer': 'Charles produced Modern Sounds in Country and Western Music with Sid Feller'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_7241_3',
#     'original_question': 'What year was it released?',
#     'answer': 'Modern Sounds in Country and Western Music was releasded in 1962'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_7241_4',
#     'original_question': 'What was a song from the album?',
#     'answer': "Singles from Modern Sounds in Country and Western Music include I Can't Stop Loving You“"},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_7241_5',
#     'original_question': 'What type of music in on the album?',
#     'answer': 'Modern Sounds in Country and Western Music featured country, folk, and Western music standards reworked by Charles in popular song forms of the time, including R&B, pop, and jazz.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_7241_6',
#     'original_question': 'Did he have a lot of creative control?',
#     'answer': 'In the process of recording the album, Charles became one of the first African-American musicians to exercise complete artistic control over his own recording career.'},
#    {'turn_num': 6,
#     'sample_id': 'QReCC-Train_7241_7',
#     'original_question': 'WHat did he decide to put on the album?',
#     'answer': 'To indicate specific licks he wanted emphasized for certain songs, Charles would put together voice-and-piano demos and pass them along to the arrangers'},
#    {'turn_num': 7,
#     'sample_id': 'QReCC-Train_7241_8',
#     'original_question': 'What is a notable fact regarding the album?',
#     'answer': 'Modern Sounds in Country and Western Music has been called one of the greatest albums of all time by publications such as Rolling Stone and Time.'}]},
#  'QReCC-Train_2796': {'1': {'sample_id': 'QReCC-Train_2796_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_2796_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_2796_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_2796_5',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '5': {'sample_id': 'QReCC-Train_2796_6',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 6,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2796_1',
#     'original_question': 'Where did Mihail Kogălniceanu grow up?',
#     'answer': 'Mihail Kogălniceanu was educated at Trei Ierarhi monastery before being tutored by Gherman Vida, a monk who belonged to the Transylvanian School, and was an associate of Gheorghe Șincai.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2796_2',
#     'original_question': 'Who was his mother?',
#     'answer': "Mihail's mother, Catinca née Stavilla, was, according to Mihail Kogălniceanu's own words, [from] a Romanian family in Bessarabia."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2796_3',
#     'original_question': 'Where did he go to school?',
#     'answer': 'Mihail Kogălniceanu completed his primary education in Miroslava, where he attended the Cuénim boarding school.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_2796_4',
#     'original_question': 'Did he attend any other schools?',
#     'answer': 'With support from Prince Sturdza, Mihail Kogălniceanu continued his studies abroad, originally in the French city of Lunéville, and later at the University of Berlin.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_2796_5',
#     'original_question': 'What did he study?',
#     'answer': 'At the time, Mihail Kogălniceanu became a passionate student of history, beginning his investigations into old Moldavian chronicles.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_2796_6',
#     'original_question': 'Who was his father?',
#     'answer': 'Born in Iași, he belonged to the Kogălniceanu family of Moldavian boyars, being the son of Vornic Ilie Kogălniceanu, and the great-grandson of Constantin Kogălniceanu.'}]},
#  'QReCC-Train_6284': {'1': {'sample_id': 'QReCC-Train_6284_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_6284_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6284_1',
#     'original_question': 'In what year did Frank Hague retire from politics?',
#     'answer': 'Frank Hague abruptly announced his retirement in 1947.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6284_2',
#     'original_question': 'Was there a reason he retired?',
#     'answer': 'Governor Alfred Driscoll led the effort to implement a new constitution, which streamlined state government and made it less vulnerable to control by locally based bosses like Frank Hague.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_6284_3',
#     'original_question': 'What did he do after retirement?',
#     'answer': 'Frank Hague was able to have his nephew, Frank Hague Eggers, chosen as his successor. It was generally understood that Frank Hague still held the real power.'}]},
#  'QReCC-Train_9649': {'1': {'sample_id': 'QReCC-Train_9649_2',
#    'requires_rewrite': 1,
#    'enough_context': 0},
#   '2': {'sample_id': 'QReCC-Train_9649_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_9649_1',
#     'original_question': 'how many townships are in the state of ohio',
#     'answer': 'There are 1362 current and historic townships in Ohio.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_9649_2',
#     'original_question': 'who are the elected officials',
#     'answer': 'Ohio townships have four elected officials: A three-member board of township trustees and a fiscal officer'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_9649_3',
#     'original_question': 'how long do the officials serve',
#     'answer': 'All Ohio township officials are elected to serve four-year terms in non-partisan elections.'}]},
#  'QReCC-Train_522': {'1': {'sample_id': 'QReCC-Train_522_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_522_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_522_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_522_1',
#     'original_question': "how was Sourav Ganguly's early life?",
#     'answer': "Sourav Ganguly had a luxurious childhood and was nicknamed the 'Maharaja', meaning the 'Great King'."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_522_2',
#     'original_question': 'what more is known about his childhood?',
#     'answer': 'Since the favourite sport for the people of Calcutta was football, Sourav Ganguly was initially attracted to the game.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_522_3',
#     'original_question': 'what was his early education like?',
#     'answer': "Academics came in-between his love for sports and Sourav Ganguly's mother, Nirupa Ganguly, was not very supportive of him taking up cricket or any other sport as a career."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_522_4',
#     'original_question': 'did he focus more on academics than sport?',
#     'answer': "Sourav Ganguly's brother Snehasish Ganguly supported his dream to be a cricketer and asked their father to get Sourav Ganguly enrolled in a cricket coaching camp during his summer holidays."}]},
#  'QReCC-Train_6003': {'1': {'sample_id': 'QReCC-Train_6003_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6003_1',
#     'original_question': 'Are there any other interesting aspects about Sanjay Dutt?',
#     'answer': 'Sanjay Dutt earned nominations for the Filmfare Award for Best Actor for Saajan (1991) and Khalnayak (1993).'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6003_2',
#     'original_question': 'what other movies did they appear?',
#     'answer': 'Sanjay Dutt earned his first Best Actor at the ceremony for playing a common man-turned-gangster in Vaastav: The Reality.'}]},
#  'QReCC-Train_2642': {'1': {'sample_id': 'QReCC-Train_2642_2',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_2642_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_2642_4',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_2642_5',
#    'requires_rewrite': 1,
#    'enough_context': 0},
#   '5': {'sample_id': 'QReCC-Train_2642_6',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '6': {'sample_id': 'QReCC-Train_2642_7',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '7': {'sample_id': 'QReCC-Train_2642_8',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 8,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2642_1',
#     'original_question': 'Is La Noia a novel of Alberto Moravia?',
#     'answer': 'In 1960, Moravia published La Noia (Boredom or The Empty Canvas).'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2642_2',
#     'original_question': 'What is La Noia about?',
#     'answer': 'the story of the troubled sexual relationship between a young, rich painter striving to find sense in his life and an easygoing girl in Rome.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2642_3',
#     'original_question': 'Was it well received by the public and critics?',
#     'answer': 'Becoming known as one of his most famous novels, it won the Viareggio Prize.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_2642_4',
#     'original_question': 'What did Moravia do in later life?',
#     'answer': 'In 1967 Moravia visited China, Japan and Korea.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_2642_5',
#     'original_question': 'Are there any other interesting aspects about this article?',
#     'answer': 'In 1984, Moravia was elected to the European Parliament as member from the Italian Communist Party.'},
#    {'turn_num': 5,
#     'sample_id': 'QReCC-Train_2642_6',
#     'original_question': 'What did he accomplish in Parliament?',
#     'answer': 'His experiences at Strasbourg, ending in 1988, are told in Il diario europeo (“The European Diary”). In 1985 he won the title of “European Personality.”'},
#    {'turn_num': 6,
#     'sample_id': 'QReCC-Train_2642_7',
#     'original_question': 'Was he married?',
#     'answer': 'Spouse. Elsa Morante (m. 1941–1961). Carmen Llera (m. 1984)'},
#    {'turn_num': 7,
#     'sample_id': 'QReCC-Train_2642_8',
#     'original_question': 'Whom did he marry?',
#     'answer': 'Spouse. Elsa Morante (m. 1941–1961). Carmen Llera (m. 1984)'}]},
#  'QReCC-Train_4859': {'1': {'sample_id': 'QReCC-Train_4859_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4859_1',
#     'original_question': "What year was Michael Owen's debut season with Manchester United?",
#     'answer': 'On 3 July 2009, it was announced that Michael Owen had signed a two-year deal with reigning Premier League champions Manchester United.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4859_2',
#     'original_question': 'How was he able to get that deal?',
#     'answer': 'Michael Owen said that the approach from manager Alex Ferguson was out of the blue.'}]},
#  'QReCC-Train_5818': {'1': {'sample_id': 'QReCC-Train_5818_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_5818_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_5818_1',
#     'original_question': 'Why did Lou Gramm leave?',
#     'answer': 'Lou Gramm decided to leave Foreigner in May 1990 while preparing to tour behind Long Hard Look as the opener for Steve Miller Band.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_5818_2',
#     'original_question': 'He went solo?',
#     'answer': 'After finishing this tour, Lou Gramm went on to form the short-lived band Shadow King'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_5818_3',
#     'original_question': 'How was it received?',
#     'answer': 'Although replacements were considered, Shadow King members eventually went their separate ways, with Lou Gramm and Bruce Turgon rejoining Foreigner in 1992.'}]},
#  'QReCC-Train_7280': {'1': {'sample_id': 'QReCC-Train_7280_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7280_1',
#     'original_question': "When did Criss Angel's career start?",
#     'answer': "Criss Angel's first television appearance was in 1994, where he performed as a part of a one-hour ABC primetime special entitled Secrets."},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7280_2',
#     'original_question': 'What did he do in his early career?',
#     'answer': 'Criss Angel collaborated with musician Klayton to form Angeldust, a show that combined magic with music.'}]},
#  'QReCC-Train_1040': {'1': {'sample_id': 'QReCC-Train_1040_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_1040_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_1040_4',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_1040_1',
#     'original_question': "What is Scott Walker's WEDC?",
#     'answer': 'The Wisconsin Economic Development Corporation, also known as WEDC, is a public-private agency created in 2011 by Wisconsin governor Scott Walker.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_1040_2',
#     'original_question': 'why did he replace the wedc?',
#     'answer': "In 2011, the WEDC was created by Scott Walker as a quasi-public entity to replace the state's Department of Commerce with the objective of incenting job creation in Wisconsin."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_1040_3',
#     'original_question': 'How did he give incentives to create jobs?',
#     'answer': "In 2011, the WEDC was created by Scott Walker as a quasi-public entity to replace the state's Department of Commerce with the objective of incenting job creation in Wisconsin."},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_1040_4',
#     'original_question': 'What was the result of giving incentives (did they work?)?',
#     'answer': "Based on the 27 awards from Scott Walker's incentives, 2,100 jobs had been created to date out of a total expected of 6,100."}]},
#  'QReCC-Train_8557': {'1': {'sample_id': 'QReCC-Train_8557_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_8557_3',
#    'requires_rewrite': 0,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8557_1',
#     'original_question': 'who were the puritans and where did they come from',
#     'answer': 'The Puritans were members of a religious reform movement known as Puritanism that arose within the Church of England in the late 16th century.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8557_2',
#     'original_question': 'can you tell me about the movement',
#     'answer': 'The Puritans believed the Church of England was too similar to the Roman Catholic Church and should eliminate ceremonies and practices not rooted in the Bible.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8557_3',
#     'original_question': "what are the practices the puritans didn't like",
#     'answer': 'Puritans opposed the idea that the king should be the supreme ruler over the church; instead, they believed that only Christ could rule the church.'}]},
#  'QReCC-Train_6787': {'1': {'sample_id': 'QReCC-Train_6787_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_6787_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_6787_1',
#     'original_question': 'When was Ranveer Singh born?',
#     'answer': 'Singh was born on 6 July 1985.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_6787_2',
#     'original_question': 'Where did he go to school at?',
#     'answer': 'He joined H.R. College of Commerce and Economics in Mumbai.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_6787_3',
#     'original_question': 'Was there another school he went to?',
#     'answer': 'He went to the United States where he received his Bachelor of Arts degree from Indiana University.'}]},
#  'QReCC-Train_2302': {'1': {'sample_id': 'QReCC-Train_2302_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_2302_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_2302_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_2302_1',
#     'original_question': "Are there any interesting aspects about Le Corbusier with Painting, Cubism, Purism and L'Esprit Nouveau?",
#     'answer': 'Le Corbusier moved to Paris definitively in 1917 and began his own architectural practice with his cousin, Pierre Jeanneret, a partnership that would last until the 1950s.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_2302_2',
#     'original_question': 'What took place in 1918?',
#     'answer': 'In 1918, Le Corbusier met the Cubist painter Amédée Ozenfant, in whom he recognised a kindred spirit.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_2302_3',
#     'original_question': 'Did they collaborate at all?',
#     'answer': 'Cubist painter Amédée Ozenfant encouraged him to paint, and the two began a period of collaboration.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_2302_4',
#     'original_question': 'Did they do anything other than painting?',
#     'answer': "Amédée Ozenfant and Le Corbusier began writing for a new journal, L'Esprit Nouveau, and promoted with energy and imagination his ideas of architecture."}]},
#  'QReCC-Train_7506': {'1': {'sample_id': 'QReCC-Train_7506_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7506_1',
#     'original_question': 'when does season 5 of orange is the new black come out',
#     'answer': 'The fifth season of the American comedy drama television series Orange Is the New Black premiered on Netflix on June 9, 2017,'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7506_2',
#     'original_question': 'how many episodes are there is season 5',
#     'answer': 'There are 13 episodes in season 5 of Orange is the New Black'}]},
#  'QReCC-Train_3680': {'1': {'sample_id': 'QReCC-Train_3680_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 2,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_3680_1',
#     'original_question': 'Who did the Stone poneys have record deal with?',
#     'answer': 'Venet signed the Stone Poneys to Capitol Records in the summer of 1966.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_3680_2',
#     'original_question': 'What was the first album they did after signing the deal?',
#     'answer': 'The first album, simply called The Stone Poneys'}]},
#  'QReCC-Train_4984': {'1': {'sample_id': 'QReCC-Train_4984_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_4984_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_4984_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '4': {'sample_id': 'QReCC-Train_4984_5',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 5,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_4984_1',
#     'original_question': 'When did Tammy Duckworth enter government services?',
#     'answer': 'On November 21, 2006, several weeks after losing her first congressional campaign, Tammy Duckworth was appointed Director of the Illinois Department of Veterans Affairs by Governor Rod Blagojevich.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_4984_2',
#     'original_question': 'Was she a defendant in any lawsuits?',
#     'answer': "In 2009, two Illinois Department of Veterans Affairs employees at the Anna Veteran's Home in Union County filed a lawsuit against Tammy Duckworth."},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_4984_3',
#     'original_question': 'Why did they file the suit against her?',
#     'answer': 'The lawsuit alleged that Tammy Duckworth wrongfully terminated one employee and threatened another for reports of abuse and misconduct of veterans while head of the Illinois Department of Veterans Affairs.'},
#    {'turn_num': 3,
#     'sample_id': 'QReCC-Train_4984_4',
#     'original_question': 'Was she found guilty of these charges?',
#     'answer': 'The case was dismissed twice but refilings were allowed. The court set a tentative trial date of August 2016 and rejected the final motion to dismiss.'},
#    {'turn_num': 4,
#     'sample_id': 'QReCC-Train_4984_5',
#     'original_question': 'What was the final outcome of the case?',
#     'answer': 'The state announced that it had settled the case in June 2016 for $26,000 with no admission of wrongdoing.'}]},
#  'QReCC-Train_7194': {'1': {'sample_id': 'QReCC-Train_7194_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_7194_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 3,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_7194_1',
#     'original_question': 'When was Rajinikanth hospitalized?',
#     'answer': 'During the principal photography of Rana on 29 April 2011 he was hospitalized.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_7194_2',
#     'original_question': 'Why was he in the hospital?',
#     'answer': 'Rajinikanth suffered a mild foodborne illness, which led to vomiting, dehydration, and exhaustion.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_7194_3',
#     'original_question': 'How long was he in the hospital?',
#     'answer': "Rajinikanth was treated at St. Isabel's Hospital for a day before being discharged."}]},
#  'QReCC-Train_8733': {'1': {'sample_id': 'QReCC-Train_8733_2',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '2': {'sample_id': 'QReCC-Train_8733_3',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   '3': {'sample_id': 'QReCC-Train_8733_4',
#    'requires_rewrite': 1,
#    'enough_context': 1},
#   'number_of_turns': 4,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': 'QReCC-Train_8733_1',
#     'original_question': 'where is andes mountains located in south america',
#     'answer': 'The Andes extend from north to south through seven South American countries: Venezuela, Colombia, Ecuador, Peru, Bolivia, Chile and Argentina.'},
#    {'turn_num': 1,
#     'sample_id': 'QReCC-Train_8733_2',
#     'original_question': 'why is the range special',
#     'answer': 'The Andes, Andes Mountains or Andean Mountains (Spanish: Cordillera de los Andes) are the longest continental mountain range in the world.'},
#    {'turn_num': 2,
#     'sample_id': 'QReCC-Train_8733_3',
#     'original_question': 'how long is the range',
#     'answer': 'The Andes mountain range is 7,000 km (4,300 mi) long.'},
#    {'turn_num': 3,
# ...
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '10': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-11-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '11': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-12-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '12': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-13-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '13': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-14-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '14': {'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-15-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   'number_of_turns': 15,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-1-0',
#     'original_question': 'Is the precise cause of sexual orientation scientifically known?',
#     'answer': 'Scientists do not know the exact cause'},
#    {'turn_num': 1,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-2-0',
#     'original_question': 'what are their thoughts?',
#     'answer': 'it is caused by a complex interplay'},
#    {'turn_num': 2,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-3-0',
#     'original_question': 'of what?',
#     'answer': 'genetic, hormonal, and environmental influences'},
#    {'turn_num': 3,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-4-0',
#     'original_question': 'do they think its possible for uterine development to play a part?',
#     'answer': 'the early uterine environment'},
#    {'turn_num': 4,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-5-0',
#     'original_question': 'how does sexual orientation range?',
#     'answer': 'along a continuum'},
#    {'turn_num': 5,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-6-0',
#     'original_question': 'including what?',
#     'answer': 'exclusive attraction to the opposite sex to exclusive attraction to the same sex'},
#    {'turn_num': 6,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-7-0',
#     'original_question': 'is sexual orientation the same as sexual identity?',
#     'answer': 'they are distinguished'},
#    {'turn_num': 7,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-8-0',
#     'original_question': 'what does identity refer to?',
#     'answer': "an individual's conception of themselves"},
#    {'turn_num': 8,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-9-0',
#     'original_question': 'what about orientation?',
#     'answer': ' "fantasies, attachments and longings'},
#    {'turn_num': 9,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-10-0',
#     'original_question': 'what does it refer to when someone is "in the closet?"',
#     'answer': 'sexual orientation that does not align with their sexual identity'},
#    {'turn_num': 10,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-11-0',
#     'original_question': 'what does that term reflect?',
#     'answer': 'a certain cultural context and particular stage of transition'},
#    {'turn_num': 11,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-12-0',
#     'original_question': 'what kind of stage?',
#     'answer': 'There is no information about this'},
#    {'turn_num': 12,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-13-0',
#     'original_question': 'what terms do scientists use?',
#     'answer': 'concordance or discordance'},
#    {'turn_num': 13,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-14-0',
#     'original_question': 'what is concordance?',
#     'answer': "a person's sexual attractions, behaviors and identity match"},
#    {'turn_num': 14,
#     'sample_id': '3w8cv64qj2zqcgwbwokxot5sa7dh90-15-0',
#     'original_question': 'what is an example of discordance?',
#     'answer': ' a woman who is attracted to other women, but calls herself heterosexual and only has sexual relations with men'}]},
#  '3itxp059pwj481n0tun9h1qxfwajs4': {'1': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '10': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-11-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '11': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-12-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '12': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-13-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '13': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-14-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '14': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-15-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '15': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-16-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '16': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-17-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '17': {'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-18-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   'number_of_turns': 18,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-1-0',
#     'original_question': 'How much of Southern Nevada is food insecure?',
#     'answer': 'An estimated 16.2% of the Southern Nevada population is considered "food insecure,"'},
#    {'turn_num': 1,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-2-0',
#     'original_question': 'What do people usually do to help?',
#     'answer': 'When people want to give back to their community, they typically pull out their checkbooks. \n\n'},
#    {'turn_num': 2,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-3-0',
#     'original_question': 'Is Jayson Black doing something else to help?',
#     'answer': 'The 28-year-old IT consultant pledged to run 26.2 miles a day for 26 days -- a total of 681.2 miles -- to raise money and awareness for the Three Square Food Bank of Southern Nevada. \n'},
#    {'turn_num': 3,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-4-0',
#     'original_question': 'What?',
#     'answer': 'The 28-year-old IT consultant pledged to run 26.2 miles a day for 26 days -- a total of 681.2 miles -- to raise money and awareness for the Three Square Food Bank of Southern Nevada. \n'},
#    {'turn_num': 4,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-5-0',
#     'original_question': 'How does that help?',
#     'answer': 'The 28-year-old IT consultant pledged to run 26.2 miles a day for 26 days -- a total of 681.2 miles -- to raise money and awareness for the Three Square Food Bank of Southern Nevada. \n'},
#    {'turn_num': 5,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-6-0',
#     'original_question': "How did that come to CNN's attention?",
#     'answer': "Black first came to CNN's attention through longtime iReporter Chris Morrow, who was in Las Vegas and read about his campaign. \n"},
#    {'turn_num': 6,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-7-0',
#     'original_question': 'How old is Black?',
#     'answer': 'The 28-year-old IT consultant'},
#    {'turn_num': 7,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-8-0',
#     'original_question': 'What is his day job?',
#     'answer': 'The 28-year-old IT consultant'},
#    {'turn_num': 8,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-9-0',
#     'original_question': 'How is he juggling his work with his daily marathon?',
#     'answer': 'There is no information about this'},
#    {'turn_num': 9,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-10-0',
#     'original_question': 'Is it affecting his home life any?',
#     'answer': 'Black spent Thanksgiving Day on the street. \n'},
#    {'turn_num': 10,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-11-0',
#     'original_question': 'Did he at least eat some turkey when he went home?',
#     'answer': 'Black came home for a Thanksgiving meal of salad and protein shakes. \n'},
#    {'turn_num': 11,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-12-0',
#     'original_question': 'Does he see hungry people often?',
#     'answer': '"You drive around any city in the United States, and there\'s always someone somewhere holding a sign or digging through a garbage can for something to eat,"'},
#    {'turn_num': 12,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-13-0',
#     'original_question': "How does he know they're hungry?",
#     'answer': "there's always someone somewhere holding a sign or digging through a garbage can for something to eat,"},
#    {'turn_num': 13,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-14-0',
#     'original_question': 'Does he resent people who donate turkeys at thanksgiving?',
#     'answer': '"It\'s great that everyone donates a turkey at Thanksgiving'},
#    {'turn_num': 14,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-15-0',
#     'original_question': 'What does he say about hunger and Thanksgiving?',
#     'answer': ' "It\'s great that everyone donates a turkey at Thanksgiving, but this is something bigger than just Thanksgiving." '},
#    {'turn_num': 15,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-16-0',
#     'original_question': 'What did he eat on Thanksgiving?',
#     'answer': 'Black came home for a Thanksgiving meal of salad and protein shakes. \n'},
#    {'turn_num': 16,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-17-0',
#     'original_question': 'Is he complaining about that?',
#     'answer': "He's not complaining."},
#    {'turn_num': 17,
#     'sample_id': '3itxp059pwj481n0tun9h1qxfwajs4-18-0',
#     'original_question': 'Why not?',
#     'answer': 'He says he started this challenge to draw attention to impoverished people who go hungry on a daily basis. \n'}]},
#  '37qw5d2zrgmfokrh2qqisbhjznms83': {'1': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '6': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-7-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '7': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-8-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '8': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-9-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '9': {'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-10-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   'number_of_turns': 10,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-1-0',
#     'original_question': 'Who was searching in vain?',
#     'answer': "Signor Andrea D'Arbino"},
#    {'turn_num': 1,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-2-0',
#     'original_question': 'Who was he searching for?',
#     'answer': "Count Fabio d'Ascoli"},
#    {'turn_num': 2,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-3-0',
#     'original_question': 'Where was he searching?',
#     'answer': 'in the palace'},
#    {'turn_num': 3,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-4-0',
#     'original_question': 'Where did he try last?',
#     'answer': 'the corridor leading to the ballroom'},
#    {'turn_num': 4,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-5-0',
#     'original_question': 'Did he find him there?',
#     'answer': 'discovered his friend lying on the floor'},
#    {'turn_num': 5,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-6-0',
#     'original_question': 'What was he doing?',
#     'answer': 'lying on the floor'},
#    {'turn_num': 6,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-7-0',
#     'original_question': "Who did D'Arbino go to seek help?",
#     'answer': 'in the antechamber'},
#    {'turn_num': 7,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-8-0',
#     'original_question': 'Did he find anyone there?',
#     'answer': "marquis's valet"},
#    {'turn_num': 8,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-9-0',
#     'original_question': 'What was he doing?',
#     'answer': 'assisting the Cavaliere Finello'},
#    {'turn_num': 9,
#     'sample_id': '37qw5d2zrgmfokrh2qqisbhjznms83-10-0',
#     'original_question': 'Where did they carry Fabio to?',
#     'answer': 'to an open window'}]},
#  '31ibvunm9sz4vri84z1tdqickjufvo': {'1': {'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-2-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '2': {'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-3-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '3': {'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-4-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '4': {'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-5-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   '5': {'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-6-0',
#    'requires_rewrite': None,
#    'enough_context': None},
#   'number_of_turns': 6,
#   'annotator_id': 'ori',
#   'dialog': [{'turn_num': 0,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-1-0',
#     'original_question': 'Where the message get sent?',
#     'answer': 'Having sent their message to the Fords'},
#    {'turn_num': 1,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-2-0',
#     'original_question': 'Where are they going?',
#     'answer': 'in the direction where the farmer had said the constable lived'},
#    {'turn_num': 2,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-3-0',
#     'original_question': 'How far did they go before they found them?',
#     'answer': 'A block had been covered when they saw the farmer and the constable approaching'},
#    {'turn_num': 3,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-4-0',
#     'original_question': 'Who had dressed themself as police?',
#     'answer': "Jed Plodders had pinned a bright, silver star, and he carried a policeman's club in his hand"},
#    {'turn_num': 4,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-5-0',
#     'original_question': 'Are they trying to get them to cease?',
#     'answer': '"Stop!" cried the constable, and pointed his club at the cadets.'},
#    {'turn_num': 5,
#     'sample_id': '31ibvunm9sz4vri84z1tdqickjufvo-6-0',
#     'original_question': 'What are they accusing them of?',
#     'answer': "You broke into Mr. Ford's house, didn't you?"}]},
#  ...}
